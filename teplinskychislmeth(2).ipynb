# %% [markdown]
# # Численные методы

# %% [markdown]
# Используемые библиотеки:
# - numpy
# - pandas
# - matplotlib.pyplot
# - seaborn
# - math

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

sns.set_theme(style="whitegrid", palette="deep")
plt.rcParams["figure.figsize"] = (8, 6)

def table(df):
    return df.style.set_table_styles(
        [
            {"selector": "th", "props": [("background-color", "#4F4F4F"), ("color", "white"), ("font-size", "12pt")]},
            {"selector": "td", "props": [("font-size", "11pt")]}
        ]
    ).set_properties(**{"text-align": "center"})

def scan(func, a, b, h):
    xs = np.arange(a, b + h, h, dtype=float)
    out = []
    x0 = xs[0]
    y0 = func(x0)
    for x1 in xs[1:]:
        y1 = func(x1)
        if y0 == 0 or y1 == 0 or y0 * y1 < 0:
            out.append((float(x0), float(x1)))
        x0, y0 = x1, y1
    return out

def show_intervals(intervals, digits=1):
    parts = []
    for a, b in intervals:
        ra = round(a, digits)
        rb = round(b, digits)
        if abs(ra) < 10**(-digits):
            ra = 0
        if abs(rb) < 10**(-digits):
            rb = 0
        parts.append(f"[{ra}; {rb}]")
    return ", ".join(parts)

def roots_on_grid(x, y):
    idx = np.where(y[:-1] * y[1:] <= 0)[0]
    roots = []
    for i in idx:
        x0, x1 = x[i], x[i + 1]
        y0, y1 = y[i], y[i + 1]
        if y0 == 0:
            r = x0
        elif y1 == 0:
            r = x1
        else:
            r = x0 - y0 * (x1 - x0) / (y1 - y0)
        if not roots or abs(r - roots[-1]) > 1e-3:
            roots.append(float(r))
    return roots

def bisection(func, a, b, eps):
    rows = []
    fa = func(a)
    fb = func(b)
    n = 0
    while (b - a) / 2 > eps:
        c = (a + b) / 2
        fc = func(c)
        rows.append([n, round(a, 6), round(b, 6), round(c, 6), round(fc, 6), round((b - a) / 2, 6)])
        if fa * fc <= 0:
            b = c
            fb = fc
        else:
            a = c
            fa = fc
        n += 1
    return (a + b) / 2, rows

def simple_iterations(phi, x0, eps, limit=100):
    rows = []
    x = x0
    for n in range(limit):
        xn = phi(x)
        d = abs(xn - x)
        rows.append([n, round(x, 6), round(xn, 6), round(d, 6)])
        if d < eps:
            return xn, rows
        x = xn
    return xn, rows

# %% [markdown]
# ## 2.1
# ### Упражнение 1
# а) $\lg x + 6 = x^2$

# %%
x = np.linspace(1e-6, 4, 2500)
y1 = np.log10(x) + 6
y2 = x**2
r = roots_on_grid(x, y1 - y2)

plt.figure(figsize=(8, 6))
plt.plot(x, y1, label="lg(x) + 6", linewidth=2)
plt.plot(x, y2, label="x^2", linewidth=2)

for xi in r:
    yi = np.interp(xi, x, y1)
    plt.scatter(xi, yi, color="black", zorder=5)
    plt.vlines(xi, 0, yi, colors="red", linestyles="dashed", linewidth=1.5)

plt.xlim(0, 4)
plt.ylim(-1, 8)
plt.title("Графическое отделение корней", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

f = lambda t: math.log10(t) + 6 - t**2
intervals = scan(f, 1e-6, 4, 0.1)
print("Ответ:", show_intervals(intervals))
# Out:
# Ответ: [0; 0.1], [2.5; 2.6]

# %% [markdown]
# б) $x\sin x - 1 = 0$

# %%
x1 = np.linspace(-10, -0.2, 3000)
x2 = np.linspace(0.2, 10, 3000)
d1 = np.sin(x1) - 1 / x1
d2 = np.sin(x2) - 1 / x2
r = roots_on_grid(x1, d1) + roots_on_grid(x2, d2)

plt.figure(figsize=(10, 6))
plt.plot(x1, np.sin(x1), linewidth=2, label="sin(x)")
plt.plot(x2, np.sin(x2), linewidth=2)
plt.plot(x1, 1 / x1, linewidth=2, label="1/x")
plt.plot(x2, 1 / x2, linewidth=2)

for xi in r:
    yi = math.sin(xi)
    plt.scatter(xi, yi, color="black", zorder=5)
    plt.vlines(xi, 0, yi, colors="red", linestyles="dashed", linewidth=1.2)

plt.xlim(-10, 10)
plt.ylim(-2, 2)
plt.title("Графическое отделение корней", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

g = lambda t: t * math.sin(t) - 1
intervals = scan(g, -10, 10, 0.1)
print("Ответ:", show_intervals(intervals))
# Out:
# Ответ: [-9.4; -9.3], [-6.5; -6.4], [-2.8; -2.7], [-1.2; -1.1], [1.1; 1.2], [2.7; 2.8], [6.4; 6.5], [9.3; 9.4]

# %% [markdown]
# ## 2.2
# ### Упражнение
# $x\sin x - 1 = 0$, метод половинного деления, $\varepsilon = 10^{-4}$

# %%
f = lambda x: x * math.sin(x) - 1
x, rows = bisection(f, 1.1, 1.2, 1e-4)
df = pd.DataFrame(rows, columns=["n", "a", "b", "c", "f(c)", "Δ"])
display(table(df))
print(f"Ответ: x ≈ {x:.6f}")
# Out:
# <style type="text/css">
# #T_7dd2d th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_7dd2d td {
#   font-size: 11pt;
# }
# #T_7dd2d_row0_col0, #T_7dd2d_row0_col1, #T_7dd2d_row0_col2, #T_7dd2d_row0_col3, #T_7dd2d_row0_col4, #T_7dd2d_row0_col5, #T_7dd2d_row1_col0, #T_7dd2d_row1_col1, #T_7dd2d_row1_col2, #T_7dd2d_row1_col3, #T_7dd2d_row1_col4, #T_7dd2d_row1_col5, #T_7dd2d_row2_col0, #T_7dd2d_row2_col1, #T_7dd2d_row2_col2, #T_7dd2d_row2_col3, #T_7dd2d_row2_col4, #T_7dd2d_row2_col5, #T_7dd2d_row3_col0, #T_7dd2d_row3_col1, #T_7dd2d_row3_col2, #T_7dd2d_row3_col3, #T_7dd2d_row3_col4, #T_7dd2d_row3_col5, #T_7dd2d_row4_col0, #T_7dd2d_row4_col1, #T_7dd2d_row4_col2, #T_7dd2d_row4_col3, #T_7dd2d_row4_col4, #T_7dd2d_row4_col5, #T_7dd2d_row5_col0, #T_7dd2d_row5_col1, #T_7dd2d_row5_col2, #T_7dd2d_row5_col3, #T_7dd2d_row5_col4, #T_7dd2d_row5_col5, #T_7dd2d_row6_col0, #T_7dd2d_row6_col1, #T_7dd2d_row6_col2, #T_7dd2d_row6_col3, #T_7dd2d_row6_col4, #T_7dd2d_row6_col5, #T_7dd2d_row7_col0, #T_7dd2d_row7_col1, #T_7dd2d_row7_col2, #T_7dd2d_row7_col3, #T_7dd2d_row7_col4, #T_7dd2d_row7_col5, #T_7dd2d_row8_col0, #T_7dd2d_row8_col1, #T_7dd2d_row8_col2, #T_7dd2d_row8_col3, #T_7dd2d_row8_col4, #T_7dd2d_row8_col5 {
#   text-align: center;
# }
# </style>
# <table id="T_7dd2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dd2d_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_7dd2d_level0_col1" class="col_heading level0 col1" >a</th>
#       <th id="T_7dd2d_level0_col2" class="col_heading level0 col2" >b</th>
#       <th id="T_7dd2d_level0_col3" class="col_heading level0 col3" >c</th>
#       <th id="T_7dd2d_level0_col4" class="col_heading level0 col4" >f(c)</th>
#       <th id="T_7dd2d_level0_col5" class="col_heading level0 col5" >Δ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dd2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7dd2d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7dd2d_row0_col1" class="data row0 col1" >1.100000</td>
#       <td id="T_7dd2d_row0_col2" class="data row0 col2" >1.200000</td>
#       <td id="T_7dd2d_row0_col3" class="data row0 col3" >1.150000</td>
#       <td id="T_7dd2d_row0_col4" class="data row0 col4" >0.049679</td>
#       <td id="T_7dd2d_row0_col5" class="data row0 col5" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7dd2d_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7dd2d_row1_col1" class="data row1 col1" >1.100000</td>
#       <td id="T_7dd2d_row1_col2" class="data row1 col2" >1.150000</td>
#       <td id="T_7dd2d_row1_col3" class="data row1 col3" >1.125000</td>
#       <td id="T_7dd2d_row1_col4" class="data row1 col4" >0.015051</td>
#       <td id="T_7dd2d_row1_col5" class="data row1 col5" >0.025000</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7dd2d_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_7dd2d_row2_col1" class="data row2 col1" >1.100000</td>
#       <td id="T_7dd2d_row2_col2" class="data row2 col2" >1.125000</td>
#       <td id="T_7dd2d_row2_col3" class="data row2 col3" >1.112500</td>
#       <td id="T_7dd2d_row2_col4" class="data row2 col4" >-0.002302</td>
#       <td id="T_7dd2d_row2_col5" class="data row2 col5" >0.012500</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7dd2d_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_7dd2d_row3_col1" class="data row3 col1" >1.112500</td>
#       <td id="T_7dd2d_row3_col2" class="data row3 col2" >1.125000</td>
#       <td id="T_7dd2d_row3_col3" class="data row3 col3" >1.118750</td>
#       <td id="T_7dd2d_row3_col4" class="data row3 col4" >0.006377</td>
#       <td id="T_7dd2d_row3_col5" class="data row3 col5" >0.006250</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7dd2d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_7dd2d_row4_col1" class="data row4 col1" >1.112500</td>
#       <td id="T_7dd2d_row4_col2" class="data row4 col2" >1.118750</td>
#       <td id="T_7dd2d_row4_col3" class="data row4 col3" >1.115625</td>
#       <td id="T_7dd2d_row4_col4" class="data row4 col4" >0.002038</td>
#       <td id="T_7dd2d_row4_col5" class="data row4 col5" >0.003125</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7dd2d_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_7dd2d_row5_col1" class="data row5 col1" >1.112500</td>
#       <td id="T_7dd2d_row5_col2" class="data row5 col2" >1.115625</td>
#       <td id="T_7dd2d_row5_col3" class="data row5 col3" >1.114063</td>
#       <td id="T_7dd2d_row5_col4" class="data row5 col4" >-0.000131</td>
#       <td id="T_7dd2d_row5_col5" class="data row5 col5" >0.001563</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7dd2d_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_7dd2d_row6_col1" class="data row6 col1" >1.114063</td>
#       <td id="T_7dd2d_row6_col2" class="data row6 col2" >1.115625</td>
#       <td id="T_7dd2d_row6_col3" class="data row6 col3" >1.114844</td>
#       <td id="T_7dd2d_row6_col4" class="data row6 col4" >0.000954</td>
#       <td id="T_7dd2d_row6_col5" class="data row6 col5" >0.000781</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7dd2d_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_7dd2d_row7_col1" class="data row7 col1" >1.114063</td>
#       <td id="T_7dd2d_row7_col2" class="data row7 col2" >1.114844</td>
#       <td id="T_7dd2d_row7_col3" class="data row7 col3" >1.114453</td>
#       <td id="T_7dd2d_row7_col4" class="data row7 col4" >0.000411</td>
#       <td id="T_7dd2d_row7_col5" class="data row7 col5" >0.000391</td>
#     </tr>
#     <tr>
#       <th id="T_7dd2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7dd2d_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_7dd2d_row8_col1" class="data row8 col1" >1.114063</td>
#       <td id="T_7dd2d_row8_col2" class="data row8 col2" >1.114453</td>
#       <td id="T_7dd2d_row8_col3" class="data row8 col3" >1.114258</td>
#       <td id="T_7dd2d_row8_col4" class="data row8 col4" >0.000140</td>
#       <td id="T_7dd2d_row8_col5" class="data row8 col5" >0.000195</td>
#     </tr>
#   </tbody>
# </table>
# Ответ: x ≈ 1.114160

# %% [markdown]
# ## 2.3
# ### Упражнение 1
# Графическая иллюстрация сходящегося итерационного процесса

# %%
phi = lambda x: 1 - 0.5 * x
a, b = 0, 2
x = np.linspace(a, b, 500)
y = phi(x)

points = [1.5]
for _ in range(8):
    points.append(phi(points[-1]))

plt.figure(figsize=(8, 6))
plt.plot(x, y, linewidth=2, label="y = f(x)")
plt.plot(x, x, linewidth=2, linestyle="--", color="gray", label="y = x")

for i in range(len(points) - 1):
    plt.plot([points[i], points[i]], [points[i], points[i + 1]], color="red", linewidth=1.5)
    plt.plot([points[i], points[i + 1]], [points[i + 1], points[i + 1]], color="red", linewidth=1.5)

plt.xlim(a, b)
plt.ylim(a, b)
plt.title("Сходящийся итерационный процесс", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Упражнение 2
# $x\sin x - 1 = 0$, метод простой итерации, $\varepsilon = 10^{-5}$

# %%
F = lambda x: x * math.sin(x) - 1
phi = lambda x: x - 0.5 * F(x)

x, rows = simple_iterations(phi, 1.0, 1e-5)
df = pd.DataFrame(rows, columns=["n", "x_n", "x_(n+1)", "|x_(n+1)-x_n|"])
display(table(df))
print(f"Ответ: x ≈ {x:.6f}")
# Out:
# <style type="text/css">
# #T_05688 th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_05688 td {
#   font-size: 11pt;
# }
# #T_05688_row0_col0, #T_05688_row0_col1, #T_05688_row0_col2, #T_05688_row0_col3, #T_05688_row1_col0, #T_05688_row1_col1, #T_05688_row1_col2, #T_05688_row1_col3, #T_05688_row2_col0, #T_05688_row2_col1, #T_05688_row2_col2, #T_05688_row2_col3, #T_05688_row3_col0, #T_05688_row3_col1, #T_05688_row3_col2, #T_05688_row3_col3, #T_05688_row4_col0, #T_05688_row4_col1, #T_05688_row4_col2, #T_05688_row4_col3, #T_05688_row5_col0, #T_05688_row5_col1, #T_05688_row5_col2, #T_05688_row5_col3, #T_05688_row6_col0, #T_05688_row6_col1, #T_05688_row6_col2, #T_05688_row6_col3, #T_05688_row7_col0, #T_05688_row7_col1, #T_05688_row7_col2, #T_05688_row7_col3, #T_05688_row8_col0, #T_05688_row8_col1, #T_05688_row8_col2, #T_05688_row8_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_05688" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05688_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_05688_level0_col1" class="col_heading level0 col1" >x_n</th>
#       <th id="T_05688_level0_col2" class="col_heading level0 col2" >x_(n+1)</th>
#       <th id="T_05688_level0_col3" class="col_heading level0 col3" >|x_(n+1)-x_n|</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05688_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05688_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_05688_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_05688_row0_col2" class="data row0 col2" >1.079265</td>
#       <td id="T_05688_row0_col3" class="data row0 col3" >0.079265</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05688_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_05688_row1_col1" class="data row1 col1" >1.079265</td>
#       <td id="T_05688_row1_col2" class="data row1 col2" >1.103519</td>
#       <td id="T_05688_row1_col3" class="data row1 col3" >0.024254</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05688_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_05688_row2_col1" class="data row2 col1" >1.103519</td>
#       <td id="T_05688_row2_col2" class="data row2 col2" >1.110909</td>
#       <td id="T_05688_row2_col3" class="data row2 col3" >0.007390</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05688_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_05688_row3_col1" class="data row3 col1" >1.110909</td>
#       <td id="T_05688_row3_col2" class="data row3 col2" >1.113165</td>
#       <td id="T_05688_row3_col3" class="data row3 col3" >0.002256</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05688_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_05688_row4_col1" class="data row4 col1" >1.113165</td>
#       <td id="T_05688_row4_col2" class="data row4 col2" >1.113854</td>
#       <td id="T_05688_row4_col3" class="data row4 col3" >0.000689</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05688_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_05688_row5_col1" class="data row5 col1" >1.113854</td>
#       <td id="T_05688_row5_col2" class="data row5 col2" >1.114064</td>
#       <td id="T_05688_row5_col3" class="data row5 col3" >0.000211</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_05688_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_05688_row6_col1" class="data row6 col1" >1.114064</td>
#       <td id="T_05688_row6_col2" class="data row6 col2" >1.114129</td>
#       <td id="T_05688_row6_col3" class="data row6 col3" >0.000064</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_05688_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_05688_row7_col1" class="data row7 col1" >1.114129</td>
#       <td id="T_05688_row7_col2" class="data row7 col2" >1.114148</td>
#       <td id="T_05688_row7_col3" class="data row7 col3" >0.000020</td>
#     </tr>
#     <tr>
#       <th id="T_05688_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_05688_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_05688_row8_col1" class="data row8 col1" >1.114148</td>
#       <td id="T_05688_row8_col2" class="data row8 col2" >1.114154</td>
#       <td id="T_05688_row8_col3" class="data row8 col3" >0.000006</td>
#     </tr>
#   </tbody>
# </table>
# Ответ: x ≈ 1.114154

# %% [markdown]
# ## 2.5
# ### Упражнение 1
# Графическая иллюстрация методов хорд и касательных

# %%
def plot_case(ax, f, df, a, b, c, title):
    x = np.linspace(a, b, 500)
    y = f(x)
    ax.plot(x, y, linewidth=2)
    ax.axhline(0, color="black", linewidth=1)
    ax.axvline(0, color="black", linewidth=1)
    y0 = f(c)
    y1 = f(a + b - c)
    xx = np.linspace(a, b, 200)
    ax.plot(xx, y0 + df(c) * (xx - c), linestyle="--", linewidth=1.5)
    ax.plot([c, a + b - c], [y0, y1], linewidth=1.5)
    ax.scatter([c, a + b - c], [y0, y1], color="black", s=25)
    ax.set_title(title)
    ax.set_xlabel("x")
    ax.set_ylabel("F(x)")

fig, axes = plt.subplots(2, 2, figsize=(12, 9))

plot_case(axes[0, 0], lambda x: 1 - x - x**2, lambda x: -1 - 2*x, 0, 1.2, 1.2, "а) F' < 0, F'' < 0")
plot_case(axes[0, 1], lambda x: np.exp(-x) - 0.3, lambda x: -np.exp(-x), 0, 2, 0, "б) F' < 0, F'' > 0")
plot_case(axes[1, 0], lambda x: x**2 - 1, lambda x: 2*x, 0, 2, 2, "в) F' > 0, F'' > 0")
plot_case(axes[1, 1], lambda x: np.log(x) + 0.2, lambda x: 1/x, 0.4, 2, 0.4, "г) F' > 0, F'' < 0")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Упражнение 2
# $x^3 + 3x^2 - 24x + 1 = 0$, комбинированный метод, $[0; 1]$, $\varepsilon = 10^{-6}$

# %%
F = lambda x: x**3 + 3*x**2 - 24*x + 1
dF = lambda x: 3*x**2 + 6*x - 24
ddF = lambda x: 6*x + 6

a, b = 0, 1
if F(a) * ddF(a) > 0:
    c = a
    xt = a
    xh = b
else:
    c = b
    xt = b
    xh = a

rows = []
for n in range(20):
    xt1 = xt - F(xt) / dF(xt)
    xh1 = (c * F(xh) - xh * F(c)) / (F(xh) - F(c))
    mid = (xt1 + xh1) / 2
    d = abs(xt1 - xh1) / 2
    rows.append([n, round(xt1, 6), round(xh1, 6), round(mid, 6), round(d, 6)])
    if d < 1e-6:
        break
    xt, xh = xt1, xh1

df = pd.DataFrame(rows, columns=["n", "касат.", "хорды", "середина", "Δ"])
display(table(df))
print(f"Ответ: x ≈ {mid:.6f}")
# Out:
# <style type="text/css">
# #T_7d6b7 th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_7d6b7 td {
#   font-size: 11pt;
# }
# #T_7d6b7_row0_col0, #T_7d6b7_row0_col1, #T_7d6b7_row0_col2, #T_7d6b7_row0_col3, #T_7d6b7_row0_col4, #T_7d6b7_row1_col0, #T_7d6b7_row1_col1, #T_7d6b7_row1_col2, #T_7d6b7_row1_col3, #T_7d6b7_row1_col4, #T_7d6b7_row2_col0, #T_7d6b7_row2_col1, #T_7d6b7_row2_col2, #T_7d6b7_row2_col3, #T_7d6b7_row2_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_7d6b7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d6b7_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_7d6b7_level0_col1" class="col_heading level0 col1" >касат.</th>
#       <th id="T_7d6b7_level0_col2" class="col_heading level0 col2" >хорды</th>
#       <th id="T_7d6b7_level0_col3" class="col_heading level0 col3" >середина</th>
#       <th id="T_7d6b7_level0_col4" class="col_heading level0 col4" >Δ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d6b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d6b7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7d6b7_row0_col1" class="data row0 col1" >0.041667</td>
#       <td id="T_7d6b7_row0_col2" class="data row0 col2" >0.050000</td>
#       <td id="T_7d6b7_row0_col3" class="data row0 col3" >0.045833</td>
#       <td id="T_7d6b7_row0_col4" class="data row0 col4" >0.004167</td>
#     </tr>
#     <tr>
#       <th id="T_7d6b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d6b7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7d6b7_row1_col1" class="data row1 col1" >0.041889</td>
#       <td id="T_7d6b7_row1_col2" class="data row1 col2" >0.041933</td>
#       <td id="T_7d6b7_row1_col3" class="data row1 col3" >0.041911</td>
#       <td id="T_7d6b7_row1_col4" class="data row1 col4" >0.000022</td>
#     </tr>
#     <tr>
#       <th id="T_7d6b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d6b7_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_7d6b7_row2_col1" class="data row2 col1" >0.041889</td>
#       <td id="T_7d6b7_row2_col2" class="data row2 col2" >0.041889</td>
#       <td id="T_7d6b7_row2_col3" class="data row2 col3" >0.041889</td>
#       <td id="T_7d6b7_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# Ответ: x ≈ 0.041889

# %% [markdown]
# ## 2.6
# ### Упражнение 1
# $\lg x - \cos x = 0$, метод половинного деления

# %%
x = np.linspace(0.1, 8, 3000)
y1 = np.log10(x)
y2 = np.cos(x)
r = roots_on_grid(x, y1 - y2)

plt.figure(figsize=(8, 6))
plt.plot(x, y1, linewidth=2, label="lg(x)")
plt.plot(x, y2, linewidth=2, label="cos(x)")

for xi in r:
    yi = np.interp(xi, x, y1)
    plt.scatter(xi, yi, color="black", zorder=5)
    plt.vlines(xi, 0, yi, colors="red", linestyles="dashed", linewidth=1.2)

plt.xlim(0, 8)
plt.ylim(-1.5, 1.5)
plt.title("Графическое отделение корней", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

f = lambda x: math.log10(x) - math.cos(x)
print("Ответ:", "[1; 2], [5; 6], [6; 7]")

x, rows = bisection(f, 1, 2, 1e-4)
df = pd.DataFrame(rows, columns=["n", "a", "b", "c", "f(c)", "Δ"])
display(table(df))
print(f"Корень: x ≈ {x:.4f}")
# Out:
# Ответ: [1; 2], [5; 6], [6; 7]
# <style type="text/css">
# #T_81f3a th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_81f3a td {
#   font-size: 11pt;
# }
# #T_81f3a_row0_col0, #T_81f3a_row0_col1, #T_81f3a_row0_col2, #T_81f3a_row0_col3, #T_81f3a_row0_col4, #T_81f3a_row0_col5, #T_81f3a_row1_col0, #T_81f3a_row1_col1, #T_81f3a_row1_col2, #T_81f3a_row1_col3, #T_81f3a_row1_col4, #T_81f3a_row1_col5, #T_81f3a_row2_col0, #T_81f3a_row2_col1, #T_81f3a_row2_col2, #T_81f3a_row2_col3, #T_81f3a_row2_col4, #T_81f3a_row2_col5, #T_81f3a_row3_col0, #T_81f3a_row3_col1, #T_81f3a_row3_col2, #T_81f3a_row3_col3, #T_81f3a_row3_col4, #T_81f3a_row3_col5, #T_81f3a_row4_col0, #T_81f3a_row4_col1, #T_81f3a_row4_col2, #T_81f3a_row4_col3, #T_81f3a_row4_col4, #T_81f3a_row4_col5, #T_81f3a_row5_col0, #T_81f3a_row5_col1, #T_81f3a_row5_col2, #T_81f3a_row5_col3, #T_81f3a_row5_col4, #T_81f3a_row5_col5, #T_81f3a_row6_col0, #T_81f3a_row6_col1, #T_81f3a_row6_col2, #T_81f3a_row6_col3, #T_81f3a_row6_col4, #T_81f3a_row6_col5, #T_81f3a_row7_col0, #T_81f3a_row7_col1, #T_81f3a_row7_col2, #T_81f3a_row7_col3, #T_81f3a_row7_col4, #T_81f3a_row7_col5, #T_81f3a_row8_col0, #T_81f3a_row8_col1, #T_81f3a_row8_col2, #T_81f3a_row8_col3, #T_81f3a_row8_col4, #T_81f3a_row8_col5, #T_81f3a_row9_col0, #T_81f3a_row9_col1, #T_81f3a_row9_col2, #T_81f3a_row9_col3, #T_81f3a_row9_col4, #T_81f3a_row9_col5, #T_81f3a_row10_col0, #T_81f3a_row10_col1, #T_81f3a_row10_col2, #T_81f3a_row10_col3, #T_81f3a_row10_col4, #T_81f3a_row10_col5, #T_81f3a_row11_col0, #T_81f3a_row11_col1, #T_81f3a_row11_col2, #T_81f3a_row11_col3, #T_81f3a_row11_col4, #T_81f3a_row11_col5, #T_81f3a_row12_col0, #T_81f3a_row12_col1, #T_81f3a_row12_col2, #T_81f3a_row12_col3, #T_81f3a_row12_col4, #T_81f3a_row12_col5 {
#   text-align: center;
# }
# </style>
# <table id="T_81f3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81f3a_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_81f3a_level0_col1" class="col_heading level0 col1" >a</th>
#       <th id="T_81f3a_level0_col2" class="col_heading level0 col2" >b</th>
#       <th id="T_81f3a_level0_col3" class="col_heading level0 col3" >c</th>
#       <th id="T_81f3a_level0_col4" class="col_heading level0 col4" >f(c)</th>
#       <th id="T_81f3a_level0_col5" class="col_heading level0 col5" >Δ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81f3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81f3a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_81f3a_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_81f3a_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_81f3a_row0_col3" class="data row0 col3" >1.500000</td>
#       <td id="T_81f3a_row0_col4" class="data row0 col4" >0.105354</td>
#       <td id="T_81f3a_row0_col5" class="data row0 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81f3a_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_81f3a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_81f3a_row1_col2" class="data row1 col2" >1.500000</td>
#       <td id="T_81f3a_row1_col3" class="data row1 col3" >1.250000</td>
#       <td id="T_81f3a_row1_col4" class="data row1 col4" >-0.218412</td>
#       <td id="T_81f3a_row1_col5" class="data row1 col5" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81f3a_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_81f3a_row2_col1" class="data row2 col1" >1.250000</td>
#       <td id="T_81f3a_row2_col2" class="data row2 col2" >1.500000</td>
#       <td id="T_81f3a_row2_col3" class="data row2 col3" >1.375000</td>
#       <td id="T_81f3a_row2_col4" class="data row2 col4" >-0.056245</td>
#       <td id="T_81f3a_row2_col5" class="data row2 col5" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81f3a_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_81f3a_row3_col1" class="data row3 col1" >1.375000</td>
#       <td id="T_81f3a_row3_col2" class="data row3 col2" >1.500000</td>
#       <td id="T_81f3a_row3_col3" class="data row3 col3" >1.437500</td>
#       <td id="T_81f3a_row3_col4" class="data row3 col4" >0.024706</td>
#       <td id="T_81f3a_row3_col5" class="data row3 col5" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81f3a_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_81f3a_row4_col1" class="data row4 col1" >1.375000</td>
#       <td id="T_81f3a_row4_col2" class="data row4 col2" >1.437500</td>
#       <td id="T_81f3a_row4_col3" class="data row4 col3" >1.406250</td>
#       <td id="T_81f3a_row4_col4" class="data row4 col4" >-0.015742</td>
#       <td id="T_81f3a_row4_col5" class="data row4 col5" >0.031250</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81f3a_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_81f3a_row5_col1" class="data row5 col1" >1.406250</td>
#       <td id="T_81f3a_row5_col2" class="data row5 col2" >1.437500</td>
#       <td id="T_81f3a_row5_col3" class="data row5 col3" >1.421875</td>
#       <td id="T_81f3a_row5_col4" class="data row5 col4" >0.004490</td>
#       <td id="T_81f3a_row5_col5" class="data row5 col5" >0.015625</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81f3a_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_81f3a_row6_col1" class="data row6 col1" >1.406250</td>
#       <td id="T_81f3a_row6_col2" class="data row6 col2" >1.421875</td>
#       <td id="T_81f3a_row6_col3" class="data row6 col3" >1.414062</td>
#       <td id="T_81f3a_row6_col4" class="data row6 col4" >-0.005624</td>
#       <td id="T_81f3a_row6_col5" class="data row6 col5" >0.007812</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81f3a_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_81f3a_row7_col1" class="data row7 col1" >1.414062</td>
#       <td id="T_81f3a_row7_col2" class="data row7 col2" >1.421875</td>
#       <td id="T_81f3a_row7_col3" class="data row7 col3" >1.417969</td>
#       <td id="T_81f3a_row7_col4" class="data row7 col4" >-0.000567</td>
#       <td id="T_81f3a_row7_col5" class="data row7 col5" >0.003906</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81f3a_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_81f3a_row8_col1" class="data row8 col1" >1.417969</td>
#       <td id="T_81f3a_row8_col2" class="data row8 col2" >1.421875</td>
#       <td id="T_81f3a_row8_col3" class="data row8 col3" >1.419922</td>
#       <td id="T_81f3a_row8_col4" class="data row8 col4" >0.001962</td>
#       <td id="T_81f3a_row8_col5" class="data row8 col5" >0.001953</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_81f3a_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_81f3a_row9_col1" class="data row9 col1" >1.417969</td>
#       <td id="T_81f3a_row9_col2" class="data row9 col2" >1.419922</td>
#       <td id="T_81f3a_row9_col3" class="data row9 col3" >1.418945</td>
#       <td id="T_81f3a_row9_col4" class="data row9 col4" >0.000698</td>
#       <td id="T_81f3a_row9_col5" class="data row9 col5" >0.000977</td>
#     </tr>
#     <tr>
#       <th id="T_81f3a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_81f3a_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_81f3a_row10_col1" class="data row10 col1" >1.417969</td>
#       <td id="T_81f3a_row10_col2" class="data row10 col2" >1.418945</td>
#       <td id="T_81f3a_row10_col3" class="data row10 col3" >1.418457</td>
#       <td id="T_81f3a_row10_col4" class="data row10 col4" >0.000065</td>
#       <td id="T_81f3a_row10_col5" class="data row10 col5" >0.000488</td>
#     </tr>
# Корень: x ≈ 1.4184

# %% [markdown]
# ### Упражнение 2
# $x^2 - 3.2x = 1$, метод простой итерации, $\varepsilon = 10^{-4}$

# %%
x = np.linspace(-1, 4, 1500)
y1 = x**2 - 3.2 * x
y2 = np.ones_like(x)
r = roots_on_grid(x, y1 - y2)

plt.figure(figsize=(8, 6))
plt.plot(x, y1, linewidth=2, label="x^2 - 3.2x")
plt.plot(x, y2, linewidth=2, label="1")

for xi in r:
    yi = np.interp(xi, x, y1)
    plt.scatter(xi, yi, color="black", zorder=5)
    plt.vlines(xi, 0, yi, colors="red", linestyles="dashed", linewidth=1.2)

plt.xlim(-1, 4)
plt.ylim(-2, 3)
plt.title("Графическое отделение корней", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

phi = lambda x: math.sqrt(3.2 * x + 1)
x, rows = simple_iterations(phi, 3.5, 1e-5)
df = pd.DataFrame(rows, columns=["n", "x_n", "x_(n+1)", "|x_(n+1)-x_n|"])
display(table(df))
print("Ответ: [-1; 0], [3; 4]")
print(f"Один корень: x ≈ {x:.4f}")
# Out:
# <style type="text/css">
# #T_5f647 th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_5f647 td {
#   font-size: 11pt;
# }
# #T_5f647_row0_col0, #T_5f647_row0_col1, #T_5f647_row0_col2, #T_5f647_row0_col3, #T_5f647_row1_col0, #T_5f647_row1_col1, #T_5f647_row1_col2, #T_5f647_row1_col3, #T_5f647_row2_col0, #T_5f647_row2_col1, #T_5f647_row2_col2, #T_5f647_row2_col3, #T_5f647_row3_col0, #T_5f647_row3_col1, #T_5f647_row3_col2, #T_5f647_row3_col3, #T_5f647_row4_col0, #T_5f647_row4_col1, #T_5f647_row4_col2, #T_5f647_row4_col3, #T_5f647_row5_col0, #T_5f647_row5_col1, #T_5f647_row5_col2, #T_5f647_row5_col3, #T_5f647_row6_col0, #T_5f647_row6_col1, #T_5f647_row6_col2, #T_5f647_row6_col3, #T_5f647_row7_col0, #T_5f647_row7_col1, #T_5f647_row7_col2, #T_5f647_row7_col3, #T_5f647_row8_col0, #T_5f647_row8_col1, #T_5f647_row8_col2, #T_5f647_row8_col3, #T_5f647_row9_col0, #T_5f647_row9_col1, #T_5f647_row9_col2, #T_5f647_row9_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_5f647" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f647_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_5f647_level0_col1" class="col_heading level0 col1" >x_n</th>
#       <th id="T_5f647_level0_col2" class="col_heading level0 col2" >x_(n+1)</th>
#       <th id="T_5f647_level0_col3" class="col_heading level0 col3" >|x_(n+1)-x_n|</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f647_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f647_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5f647_row0_col1" class="data row0 col1" >3.500000</td>
#       <td id="T_5f647_row0_col2" class="data row0 col2" >3.492850</td>
#       <td id="T_5f647_row0_col3" class="data row0 col3" >0.007150</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f647_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_5f647_row1_col1" class="data row1 col1" >3.492850</td>
#       <td id="T_5f647_row1_col2" class="data row1 col2" >3.489573</td>
#       <td id="T_5f647_row1_col3" class="data row1 col3" >0.003277</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f647_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_5f647_row2_col1" class="data row2 col1" >3.489573</td>
#       <td id="T_5f647_row2_col2" class="data row2 col2" >3.488070</td>
#       <td id="T_5f647_row2_col3" class="data row2 col3" >0.001503</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f647_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_5f647_row3_col1" class="data row3 col1" >3.488070</td>
#       <td id="T_5f647_row3_col2" class="data row3 col2" >3.487381</td>
#       <td id="T_5f647_row3_col3" class="data row3 col3" >0.000689</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f647_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_5f647_row4_col1" class="data row4 col1" >3.487381</td>
#       <td id="T_5f647_row4_col2" class="data row4 col2" >3.487064</td>
#       <td id="T_5f647_row4_col3" class="data row4 col3" >0.000316</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f647_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_5f647_row5_col1" class="data row5 col1" >3.487064</td>
#       <td id="T_5f647_row5_col2" class="data row5 col2" >3.486919</td>
#       <td id="T_5f647_row5_col3" class="data row5 col3" >0.000145</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f647_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_5f647_row6_col1" class="data row6 col1" >3.486919</td>
#       <td id="T_5f647_row6_col2" class="data row6 col2" >3.486853</td>
#       <td id="T_5f647_row6_col3" class="data row6 col3" >0.000067</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5f647_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_5f647_row7_col1" class="data row7 col1" >3.486853</td>
#       <td id="T_5f647_row7_col2" class="data row7 col2" >3.486822</td>
#       <td id="T_5f647_row7_col3" class="data row7 col3" >0.000031</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5f647_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_5f647_row8_col1" class="data row8 col1" >3.486822</td>
#       <td id="T_5f647_row8_col2" class="data row8 col2" >3.486808</td>
#       <td id="T_5f647_row8_col3" class="data row8 col3" >0.000014</td>
#     </tr>
#     <tr>
#       <th id="T_5f647_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5f647_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_5f647_row9_col1" class="data row9 col1" >3.486808</td>
#       <td id="T_5f647_row9_col2" class="data row9 col2" >3.486802</td>
#       <td id="T_5f647_row9_col3" class="data row9 col3" >0.000006</td>
#     </tr>
#   </tbody>
# </table>
# Ответ: [-1; 0], [3; 4]
# Один корень: x ≈ 3.4868

# %% [markdown]
# ### Упражнение 3
# $4x - 3\ln x = 4$, метод простой итерации, $\varepsilon = 10^{-4}$

# %%
x = np.linspace(0.1, 2, 2000)
y1 = 4 * x - 3 * np.log(x)
y2 = np.full_like(x, 4.0)
r = roots_on_grid(x, y1 - y2)

plt.figure(figsize=(8, 6))
plt.plot(x, y1, linewidth=2, label="4x - 3ln(x)")
plt.plot(x, y2, linewidth=2, label="4")

for xi in r:
    yi = np.interp(xi, x, y1)
    plt.scatter(xi, yi, color="black", zorder=5)
    plt.vlines(xi, 0, yi, colors="red", linestyles="dashed", linewidth=1.2)

plt.xlim(0, 2)
plt.ylim(0, 8)
plt.title("Графическое отделение корней", fontsize=14)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)

plt.tight_layout()
plt.show()

phi = lambda x: 1 + 0.75 * math.log(x)
x, rows = simple_iterations(phi, 1.01, 1e-5)
df = pd.DataFrame(rows, columns=["n", "x_n", "x_(n+1)", "|x_(n+1)-x_n|"])
display(table(df))
print("Ответ: [0.5; 0.6], [0.9; 1.1]")
print(f"Наибольший положительный корень: x ≈ {x:.4f}")
# Out:
# <style type="text/css">
# #T_b4637 th {
#   background-color: #4F4F4F;
#   color: white;
#   font-size: 12pt;
# }
# #T_b4637 td {
#   font-size: 11pt;
# }
# #T_b4637_row0_col0, #T_b4637_row0_col1, #T_b4637_row0_col2, #T_b4637_row0_col3, #T_b4637_row1_col0, #T_b4637_row1_col1, #T_b4637_row1_col2, #T_b4637_row1_col3, #T_b4637_row2_col0, #T_b4637_row2_col1, #T_b4637_row2_col2, #T_b4637_row2_col3, #T_b4637_row3_col0, #T_b4637_row3_col1, #T_b4637_row3_col2, #T_b4637_row3_col3, #T_b4637_row4_col0, #T_b4637_row4_col1, #T_b4637_row4_col2, #T_b4637_row4_col3, #T_b4637_row5_col0, #T_b4637_row5_col1, #T_b4637_row5_col2, #T_b4637_row5_col3, #T_b4637_row6_col0, #T_b4637_row6_col1, #T_b4637_row6_col2, #T_b4637_row6_col3, #T_b4637_row7_col0, #T_b4637_row7_col1, #T_b4637_row7_col2, #T_b4637_row7_col3, #T_b4637_row8_col0, #T_b4637_row8_col1, #T_b4637_row8_col2, #T_b4637_row8_col3, #T_b4637_row9_col0, #T_b4637_row9_col1, #T_b4637_row9_col2, #T_b4637_row9_col3, #T_b4637_row10_col0, #T_b4637_row10_col1, #T_b4637_row10_col2, #T_b4637_row10_col3, #T_b4637_row11_col0, #T_b4637_row11_col1, #T_b4637_row11_col2, #T_b4637_row11_col3, #T_b4637_row12_col0, #T_b4637_row12_col1, #T_b4637_row12_col2, #T_b4637_row12_col3, #T_b4637_row13_col0, #T_b4637_row13_col1, #T_b4637_row13_col2, #T_b4637_row13_col3, #T_b4637_row14_col0, #T_b4637_row14_col1, #T_b4637_row14_col2, #T_b4637_row14_col3, #T_b4637_row15_col0, #T_b4637_row15_col1, #T_b4637_row15_col2, #T_b4637_row15_col3, #T_b4637_row16_col0, #T_b4637_row16_col1, #T_b4637_row16_col2, #T_b4637_row16_col3, #T_b4637_row17_col0, #T_b4637_row17_col1, #T_b4637_row17_col2, #T_b4637_row17_col3, #T_b4637_row18_col0, #T_b4637_row18_col1, #T_b4637_row18_col2, #T_b4637_row18_col3, #T_b4637_row19_col0, #T_b4637_row19_col1, #T_b4637_row19_col2, #T_b4637_row19_col3, #T_b4637_row20_col0, #T_b4637_row20_col1, #T_b4637_row20_col2, #T_b4637_row20_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_b4637" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4637_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_b4637_level0_col1" class="col_heading level0 col1" >x_n</th>
#       <th id="T_b4637_level0_col2" class="col_heading level0 col2" >x_(n+1)</th>
#       <th id="T_b4637_level0_col3" class="col_heading level0 col3" >|x_(n+1)-x_n|</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4637_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4637_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b4637_row0_col1" class="data row0 col1" >1.010000</td>
#       <td id="T_b4637_row0_col2" class="data row0 col2" >1.007463</td>
#       <td id="T_b4637_row0_col3" class="data row0 col3" >0.002537</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4637_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b4637_row1_col1" class="data row1 col1" >1.007463</td>
#       <td id="T_b4637_row1_col2" class="data row1 col2" >1.005576</td>
#       <td id="T_b4637_row1_col3" class="data row1 col3" >0.001886</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4637_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b4637_row2_col1" class="data row2 col1" >1.005576</td>
#       <td id="T_b4637_row2_col2" class="data row2 col2" >1.004171</td>
#       <td id="T_b4637_row2_col3" class="data row2 col3" >0.001406</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4637_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b4637_row3_col1" class="data row3 col1" >1.004171</td>
#       <td id="T_b4637_row3_col2" class="data row3 col2" >1.003121</td>
#       <td id="T_b4637_row3_col3" class="data row3 col3" >0.001049</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4637_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b4637_row4_col1" class="data row4 col1" >1.003121</td>
#       <td id="T_b4637_row4_col2" class="data row4 col2" >1.002337</td>
#       <td id="T_b4637_row4_col3" class="data row4 col3" >0.000784</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4637_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_b4637_row5_col1" class="data row5 col1" >1.002337</td>
#       <td id="T_b4637_row5_col2" class="data row5 col2" >1.001751</td>
#       <td id="T_b4637_row5_col3" class="data row5 col3" >0.000586</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b4637_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_b4637_row6_col1" class="data row6 col1" >1.001751</td>
#       <td id="T_b4637_row6_col2" class="data row6 col2" >1.001312</td>
#       <td id="T_b4637_row6_col3" class="data row6 col3" >0.000439</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b4637_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_b4637_row7_col1" class="data row7 col1" >1.001312</td>
#       <td id="T_b4637_row7_col2" class="data row7 col2" >1.000983</td>
#       <td id="T_b4637_row7_col3" class="data row7 col3" >0.000329</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b4637_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_b4637_row8_col1" class="data row8 col1" >1.000983</td>
#       <td id="T_b4637_row8_col2" class="data row8 col2" >1.000737</td>
#       <td id="T_b4637_row8_col3" class="data row8 col3" >0.000246</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4637_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_b4637_row9_col1" class="data row9 col1" >1.000737</td>
#       <td id="T_b4637_row9_col2" class="data row9 col2" >1.000553</td>
#       <td id="T_b4637_row9_col3" class="data row9 col3" >0.000185</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b4637_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_b4637_row10_col1" class="data row10 col1" >1.000553</td>
#       <td id="T_b4637_row10_col2" class="data row10 col2" >1.000414</td>
#       <td id="T_b4637_row10_col3" class="data row10 col3" >0.000138</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b4637_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_b4637_row11_col1" class="data row11 col1" >1.000414</td>
#       <td id="T_b4637_row11_col2" class="data row11 col2" >1.000311</td>
#       <td id="T_b4637_row11_col3" class="data row11 col3" >0.000104</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b4637_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_b4637_row12_col1" class="data row12 col1" >1.000311</td>
#       <td id="T_b4637_row12_col2" class="data row12 col2" >1.000233</td>
#       <td id="T_b4637_row12_col3" class="data row12 col3" >0.000078</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b4637_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_b4637_row13_col1" class="data row13 col1" >1.000233</td>
#       <td id="T_b4637_row13_col2" class="data row13 col2" >1.000175</td>
#       <td id="T_b4637_row13_col3" class="data row13 col3" >0.000058</td>
#     </tr>
#     <tr>
#       <th id="T_b4637_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b4637_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_b4637_row14_col1" class="data row14 col1" >1.000175</td>
#       <td id="T_b4637_row14_col2" class="data row14 col2" >1.000131</td>
#       <td id="T_b4637_row14_col3" class="data row14 col3" >0.000044</td>
#     </tr>
#     <tr>
#       <th id="T_
# Ответ: [0.5; 0.6], [0.9; 1.1]
# Наибольший положительный корень: x ≈ 1.0000
